# %%
# !pip install pyyaml h5py  # Required to save models in HDF5 format
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyyaml in /usr/lib/python3/dist-packages (3.12)
# Requirement already satisfied: h5py in /home/cpslab/.local/lib/python3.6/site-packages (2.10.0)
# Requirement already satisfied: six in /home/cpslab/.local/lib/python3.6/site-packages (from h5py) (1.15.0)
# Requirement already satisfied: numpy>=1.7 in /home/cpslab/.local/lib/python3.6/site-packages (from h5py) (1.19.2)
# WARNING: You are using pip version 20.2.3; however, version 21.0 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import os
import cv2 
import numpy as np

# %%
os.listdir("/home/cpslab/Akshay KR/finished/train/dataraw/hires") #listing the contents in the location
# Out:
# ['dt_train_2296.jpg',
#  'dt_train_1253.jpg',
#  'dt_train_163.jpg',
#  'dt_train_2971.jpg',
#  'dt_train_3190.jpg',
#  'dt_train_405.jpg',
#  'dt_train_3049.jpg',
#  'dt_train_364.jpg',
#  'dt_train_1537.jpg',
#  'dt_train_2816.jpg',
#  'dt_train_1804.jpg',
#  'dt_train_428.jpg',
#  'dt_train_1535.jpg',
#  'dt_train_2884.jpg',
#  'dt_train_3339.jpg',
#  'dt_train_962.jpg',
#  'dt_train_1251.jpg',
#  'dt_train_68.jpg',
#  'dt_train_1613.jpg',
#  'dt_train_3744.jpg',
#  'dt_train_1109.jpg',
#  'dt_train_1422.jpg',
#  'dt_train_4032.jpg',
#  'dt_train_3209.jpg',
#  'dt_train_2962.jpg',
#  'dt_train_3473.jpg',
#  'dt_train_244.jpg',
#  'dt_train_1156.jpg',
#  'dt_train_2183.jpg',
#  'dt_train_2984.jpg',
#  'dt_train_1250.jpg',
#  'dt_train_3900.jpg',
#  'dt_train_115.jpg',
#  'dt_train_3659.jpg',
#  'dt_train_211.jpg',
#  'dt_train_569.jpg',
#  'dt_train_840.jpg',
#  'dt_train_33.jpg',
#  'dt_train_3202.jpg',
#  'dt_train_1426.jpg',
#  'dt_train_3682.jpg',
#  'dt_train_3122.jpg',
#  'dt_train_156.jpg',
#  'dt_train_951.jpg',
#  'dt_train_2735.jpg',
#  'dt_train_2336.jpg',
#  'dt_train_3452.jpg',
#  'dt_train_18.jpg',
#  'dt_train_1710.jpg',
#  'dt_train_2886.jpg',
#  'dt_train_3822.jpg',
#  'dt_train_3442.jpg',
#  'dt_train_3118.jpg',
#  'dt_train_3669.jpg',
#  'dt_train_867.jpg',
#  'dt_train_1380.jpg',
#  'dt_train_334.jpg',
#  'dt_train_3383.jpg',
#  'dt_train_1298.jpg',
#  'dt_train_1044.jpg',
#  'dt_train_833.jpg',
#  'dt_train_3546.jpg',
#  'dt_train_2141.jpg',
#  'dt_train_856.jpg',
#  'dt_train_87.jpg',
#  'dt_train_671.jpg',
#  'dt_train_1883.jpg',
#  'dt_train_1064.jpg',
#  'dt_train_2473.jpg',
#  'dt_train_1346.jpg',
#  'dt_train_3718.jpg',
#  'dt_train_722.jpg',
#  'dt_train_1427.jpg',
#  'dt_train_942.jpg',
#  'dt_train_3105.jpg',
#  'dt_train_3058.jpg',
#  'dt_train_1610.jpg',
#  'dt_train_2979.jpg',
#  'dt_train_3270.jpg',
#  'dt_train_2461.jpg',
#  'dt_train_2477.jpg',
#  'dt_train_2210.jpg',
#  'dt_train_124.jpg',
#  'dt_train_49.jpg',
#  'dt_train_1459.jpg',
#  'dt_train_2490.jpg',
#  'dt_train_3378.jpg',
#  'dt_train_1978.jpg',
#  'dt_train_594.jpg',
#  'dt_train_151.jpg',
#  'dt_train_952.jpg',
#  'dt_train_1231.jpg',
#  'dt_train_438.jpg',
#  'dt_train_2977.jpg',
#  'dt_train_1476.jpg',
#  'dt_train_936.jpg',
#  'dt_train_906.jpg',
#  'dt_train_1424.jpg',
#  'dt_train_665.jpg',
#  'dt_train_738.jpg',
#  'dt_train_465.jpg',
#  'dt_train_51.jpg',
#  'dt_train_3937.jpg',
#  'dt_train_4007.jpg',
#  'dt_train_3368.jpg',
#  'dt_train_1892.jpg',
#  'dt_train_2903.jpg',
#  'dt_train_989.jpg',
#  'dt_train_95.jpg',
#  'dt_train_316.jpg',
#  'dt_train_654.jpg',
#  'dt_train_624.jpg',
#  'dt_train_1823.jpg',
#  'dt_train_3282.jpg',
#  'dt_train_1294.jpg',
#  'dt_train_2488.jpg',
#  'dt_train_2264.jpg',
#  'dt_train_135.jpg',
#  'dt_train_1521.jpg',
#  'dt_train_2435.jpg',
#  'dt_train_506.jpg',
#  'dt_train_710.jpg',
#  'dt_train_2065.jpg',
#  'dt_train_82.jpg',
#  'dt_train_2712.jpg',
#  'dt_train_774.jpg',
#  'dt_train_3174.jpg',
#  'dt_train_1857.jpg',
#  'dt_train_251.jpg',
#  'dt_train_1062.jpg',
#  'dt_train_2680.jpg',
#  'dt_train_2378.jpg',
#  'dt_train_4028.jpg',
#  'dt_train_3841.jpg',
#  'dt_train_1981.jpg',
#  'dt_train_2326.jpg',
#  'dt_train_2632.jpg',
#  'dt_train_979.jpg',
#  'dt_train_1394.jpg',
#  'dt_train_2161.jpg',
#  'dt_train_1775.jpg',
#  'dt_train_756.jpg',
#  'dt_train_2828.jpg',
#  'dt_train_1751.jpg',
#  'dt_train_2231.jpg',
#  'dt_train_4026.jpg',
#  'dt_train_2899.jpg',
#  'dt_train_897.jpg',
#  'dt_train_2668.jpg',
#  'dt_train_1462.jpg',
#  'dt_train_709.jpg',
#  'dt_train_3827.jpg',
#  'dt_train_816.jpg',
#  'dt_train_2094.jpg',
#  'dt_train_3025.jpg',
#  'dt_train_210.jpg',
#  'dt_train_1771.jpg',
#  'dt_train_3707.jpg',
#  'dt_train_2163.jpg',
#  'dt_train_1524.jpg',
#  'dt_train_3506.jpg',
#  'dt_train_240.jpg',
#  'dt_train_746.jpg',
#  'dt_train_4030.jpg',
#  'dt_train_1982.jpg',
#  'dt_train_1221.jpg',
#  'dt_train_3168.jpg',
#  'dt_train_3376.jpg',
#  'dt_train_927.jpg',
#  'dt_train_3243.jpg',
#  'dt_train_1899.jpg',
#  'dt_train_1218.jpg',
#  'dt_train_1058.jpg',
#  'dt_train_1353.jpg',
#  'dt_train_577.jpg',
#  'dt_train_2377.jpg',
#  'dt_train_3239.jpg',
#  'dt_train_478.jpg',
#  'dt_train_2060.jpg',
#  'dt_train_3015.jpg',
#  'dt_train_1386.jpg',
#  'dt_train_1563.jpg',
#  'dt_train_2497.jpg',
#  'dt_train_106.jpg',
#  'dt_train_4120.jpg',
#  'dt_train_880.jpg',
#  'dt_train_3706.jpg',
#  'dt_train_3162.jpg',
#  'dt_train_2139.jpg',
#  'dt_train_3765.jpg',
#  'dt_train_3726.jpg',
#  'dt_train_2165.jpg',
#  'dt_train_2328.jpg',
#  'dt_train_1326.jpg',
#  'dt_train_3947.jpg',
#  'dt_train_943.jpg',
#  'dt_train_2246.jpg',
#  'dt_train_1635.jpg',
#  'dt_train_2638.jpg',
#  'dt_train_1727.jpg',
#  'dt_train_2039.jpg',
#  'dt_train_2628.jpg',
#  'dt_train_2383.jpg',
#  'dt_train_583.jpg',
#  'dt_train_2501.jpg',
#  'dt_train_2755.jpg',
#  'dt_train_1705.jpg',
#  'dt_train_3952.jpg',
#  'dt_train_1844.jpg',
#  'dt_train_3104.jpg',
#  'dt_train_2669.jpg',
#  'dt_train_200.jpg',
#  'dt_train_829.jpg',
#  'dt_train_3560.jpg',
#  'dt_train_3347.jpg',
#  'dt_train_3951.jpg',
#  'dt_train_3864.jpg',
#  'dt_train_1013.jpg',
#  'dt_train_166.jpg',
#  'dt_train_1008.jpg',
#  'dt_train_720.jpg',
#  'dt_train_578.jpg',
#  'dt_train_64.jpg',
#  'dt_train_3184.jpg',
#  'dt_train_1389.jpg',
#  'dt_train_4084.jpg',
#  'dt_train_1097.jpg',
#  'dt_train_1243.jpg',
#  'dt_train_1878.jpg',
#  'dt_train_36.jpg',
#  'dt_train_3629.jpg',
#  'dt_train_3086.jpg',
#  'dt_train_1033.jpg',
#  'dt_train_3622.jpg',
#  'dt_train_2800.jpg',
#  'dt_train_2349.jpg',
#  'dt_train_1632.jpg',
#  'dt_train_2552.jpg',
#  'dt_train_902.jpg',
#  'dt_train_222.jpg',
#  'dt_train_3409.jpg',
#  'dt_train_3748.jpg',
#  'dt_train_141.jpg',
#  'dt_train_512.jpg',
#  'dt_train_3885.jpg',
#  'dt_train_1745.jpg',
#  'dt_train_1976.jpg',
#  'dt_train_3997.jpg',
#  'dt_train_3459.jpg',
#  'dt_train_824.jpg',
#  'dt_train_2207.jpg',
#  'dt_train_1242.jpg',
#  'dt_train_2502.jpg',
#  'dt_train_2885.jpg',
#  'dt_train_4076.jpg',
#  'dt_train_1455.jpg',
#  'dt_train_1975.jpg',
#  'dt_train_2602.jpg',
#  'dt_train_312.jpg',
#  'dt_train_4015.jpg',
#  'dt_train_3804.jpg',
#  'dt_train_26.jpg',
#  'dt_train_1912.jpg',
#  'dt_train_1055.jpg',
#  'dt_train_1905.jpg',
#  'dt_train_1923.jpg',
#  'dt_train_1111.jpg',
#  'dt_train_3261.jpg',
#  'dt_train_2021.jpg',
#  'dt_train_3050.jpg',
#  'dt_train_2924.jpg',
#  'dt_train_1485.jpg',
#  'dt_train_2933.jpg',
#  'dt_train_228.jpg',
#  'dt_train_3753.jpg',
#  'dt_train_1934.jpg',
#  'dt_train_3979.jpg',
#  'dt_train_3734.jpg',
#  'dt_train_3440.jpg',
#  'dt_train_772.jpg',
#  'dt_train_61.jpg',
#  'dt_train_1676.jpg',
#  'dt_train_1450.jpg',
#  'dt_train_455.jpg',
#  'dt_train_102.jpg',
#  'dt_train_977.jpg',
#  'dt_train_3439.jpg',
#  'dt_train_2532.jpg',
#  'dt_train_3331.jpg',
#  'dt_train_946.jpg',
#  'dt_train_2493.jpg',
#  'dt_train_3574.jpg',
#  'dt_train_3602.jpg',
#  'dt_train_1436.jpg',
#  'dt_train_286.jpg',
#  'dt_train_3273.jpg',
#  'dt_train_639.jpg',
#  'dt_train_3742.jpg',
#  'dt_train_2130.jpg',
#  'dt_train_2634.jpg',
#  'dt_train_2507.jpg',
#  'dt_train_2999.jpg',
#  'dt_train_3651.jpg',
#  'dt_train_1548.jpg',
#  'dt_train_1558.jpg',
#  'dt_train_1805.jpg',
#  'dt_train_3839.jpg',
#  'dt_train_461.jpg',
#  'dt_train_2783.jpg',
#  'dt_train_1683.jpg',
#  'dt_train_3993.jpg',
#  'dt_train_1772.jpg',
#  'dt_train_2709.jpg',
#  'dt_train_1668.jpg',
#  'dt_train_507.jpg',
#  'dt_train_2991.jpg',
#  'dt_train_3609.jpg',
#  'dt_train_3769.jpg',
#  'dt_train_1208.jpg',
#  'dt_train_3770.jpg',
#  'dt_train_3401.jpg',
#  'dt_train_1085.jpg',
#  'dt_train_2766.jpg',
#  'dt_train_76.jpg',
#  'dt_train_1467.jpg',
#  'dt_train_3486.jpg',
#  'dt_train_270.jpg',
#  'dt_train_1687.jpg',
#  'dt_train_1609.jpg',
#  'dt_train_1334.jpg',
#  'dt_train_3886.jpg',
#  'dt_train_3916.jpg',
#  'dt_train_3660.jpg',
#  'dt_train_3936.jpg',
#  'dt_train_601.jpg',
#  'dt_train_1510.jpg',
#  'dt_train_3879.jpg',
#  'dt_train_3178.jpg',
#  'dt_train_769.jpg',
#  'dt_train_2811.jpg',
#  'dt_train_1952.jpg',
#  'dt_train_2723.jpg',
#  'dt_train_765.jpg',
#  'dt_train_1900.jpg',
#  'dt_train_164.jpg',
#  'dt_train_399.jpg',
#  'dt_train_1215.jpg',
#  'dt_train_884.jpg',
#  'dt_train_3337.jpg',
#  'dt_train_836.jpg',
#  'dt_train_1760.jpg',
#  'dt_train_3475.jpg',
#  'dt_train_673.jpg',
#  'dt_train_3928.jpg',
#  'dt_train_573.jpg',
#  'dt_train_1854.jpg',
#  'dt_train_2898.jpg',
#  'dt_train_2482.jpg',
#  'dt_train_1849.jpg',
#  'dt_train_874.jpg',
#  'dt_train_1277.jpg',
#  'dt_train_3237.jpg',
#  'dt_train_931.jpg',
#  'dt_train_1317.jpg',
#  'dt_train_3298.jpg',
#  'dt_train_2985.jpg',
#  'dt_train_490.jpg',
#  'dt_train_3685.jpg',
#  'dt_train_2128.jpg',
#  'dt_train_3868.jpg',
#  'dt_train_3998.jpg',
#  'dt_train_1392.jpg',
#  'dt_train_2113.jpg',
#  'dt_train_1164.jpg',
#  'dt_train_1396.jpg',
#  'dt_train_2234.jpg',
#  'dt_train_1636.jpg',
#  'dt_train_536.jpg',
#  'dt_train_2114.jpg',
#  'dt_train_1809.jpg',
#  'dt_train_3709.jpg',
#  'dt_train_3129.jpg',
#  'dt_train_1757.jpg',
#  'dt_train_2459.jpg',
#  'dt_train_1608.jpg',
#  'dt_train_255.jpg',
#  'dt_train_481.jpg',
#  'dt_train_183.jpg',
#  'dt_train_1961.jpg',
#  'dt_train_3935.jpg',
#  'dt_train_3031.jpg',
#  'dt_train_2050.jpg',
#  'dt_train_4093.jpg',
#  'dt_train_2763.jpg',
#  'dt_train_3912.jpg',
#  'dt_train_40.jpg',
#  'dt_train_4004.jpg',
#  'dt_train_602.jpg',
#  'dt_train_3312.jpg',
#  'dt_train_1580.jpg',
#  'dt_train_1042.jpg',
#  'dt_train_724.jpg',
#  'dt_train_2660.jpg',
#  'dt_train_3675.jpg',
#  'dt_train_152.jpg',
#  'dt_train_4019.jpg',
#  'dt_train_3272.jpg',
#  'dt_train_991.jpg',
#  'dt_train_1678.jpg',
#  'dt_train_793.jpg',
#  'dt_train_2769.jpg',
#  'dt_train_2539.jpg',
#  'dt_train_2278.jpg',
#  'dt_train_3294.jpg',
#  'dt_train_1429.jpg',
#  'dt_train_1888.jpg',
#  'dt_train_502.jpg',
#  'dt_train_1095.jpg',
#  'dt_train_3367.jpg',
#  'dt_train_1199.jpg',
#  'dt_train_3076.jpg',
#  'dt_train_3715.jpg',
#  'dt_train_560.jpg',
#  'dt_train_895.jpg',
#  'dt_train_3723.jpg',
#  'dt_train_2012.jpg',
#  'dt_train_1079.jpg',
#  'dt_train_3611.jpg',
#  'dt_train_452.jpg',
#  'dt_train_1319.jpg',
#  'dt_train_875.jpg',
#  'dt_train_1712.jpg',
#  'dt_train_825.jpg',
#  'dt_train_3601.jpg',
#  'dt_train_2470.jpg',
#  'dt_train_1869.jpg',
#  'dt_train_1004.jpg',
#  'dt_train_78.jpg',
#  'dt_train_1010.jpg',
#  'dt_train_1201.jpg',
#  'dt_train_2868.jpg',
#  'dt_train_489.jpg',
#  'dt_train_384.jpg',
#  'dt_train_2815.jpg',
#  'dt_train_1202.jpg',
#  'dt_train_3154.jpg',
#  'dt_train_3007.jpg',
#  'dt_train_3650.jpg',
#  'dt_train_2032.jpg',
#  'dt_train_731.jpg',
#  'dt_train_2363.jpg',
#  'dt_train_3816.jpg',
#  'dt_train_1457.jpg',
#  'dt_train_795.jpg',
#  'dt_train_787.jpg',
#  'dt_train_4016.jpg',
#  'dt_train_2972.jpg',
#  'dt_train_1979.jpg',
#  'dt_train_3588.jpg',
#  'dt_train_2895.jpg',
#  'dt_train_342.jpg',
#  'dt_train_140.jpg',
#  'dt_train_1121.jpg',
#  'dt_train_4068.jpg',
#  'dt_train_411.jpg',
#  'dt_train_2046.jpg',
#  'dt_train_3167.jpg',
#  'dt_train_563.jpg',
#  'dt_train_1936.jpg',
#  'dt_train_2433.jpg',
#  'dt_train_2618.jpg',
#  'dt_train_1863.jpg',
#  'dt_train_2414.jpg',
#  'dt_train_3487.jpg',
#  'dt_train_2637.jpg',
#  'dt_train_3813.jpg',
#  'dt_train_3848.jpg',
#  'dt_train_1758.jpg',
#  'dt_train_288.jpg',
#  'dt_train_1694.jpg',
#  'dt_train_2392.jpg',
#  'dt_train_3402.jpg',
#  'dt_train_3584.jpg',
#  'dt_train_649.jpg',
#  'dt_train_1342.jpg',
#  'dt_train_2686.jpg',
#  'dt_train_2784.jpg',
#  'dt_train_1054.jpg',
#  'dt_train_1463.jpg',
#  'dt_train_3820.jpg',
#  'dt_train_845.jpg',
#  'dt_train_2029.jpg',
#  'dt_train_2865.jpg',
#  'dt_train_3612.jpg',
#  'dt_train_805.jpg',
#  'dt_train_2419.jpg',
#  'dt_train_2787.jpg',
#  'dt_train_1808.jpg',
#  'dt_train_944.jpg',
#  'dt_train_2384.jpg',
#  'dt_train_1766.jpg',
#  'dt_train_103.jpg',
#  'dt_train_566.jpg',
#  'dt_train_3969.jpg',
#  'dt_train_1470.jpg',
#  'dt_train_2298.jpg',
#  'dt_train_3372.jpg',
#  'dt_train_2237.jpg',
#  'dt_train_1041.jpg',
#  'dt_train_4031.jpg',
#  'dt_train_175.jpg',
#  'dt_train_4071.jpg',
#  'dt_train_2212.jpg',
#  'dt_train_2082.jpg',
#  'dt_train_2720.jpg',
#  'dt_train_2729.jpg',
#  'dt_train_1641.jpg',
#  'dt_train_3705.jpg',
#  'dt_train_3647.jpg',
#  'dt_train_1956.jpg',
#  'dt_train_3404.jpg',
#  'dt_train_2486.jpg',
#  'dt_train_1764.jpg',
#  'dt_train_2918.jpg',
#  'dt_train_1036.jpg',
#  'dt_train_4118.jpg',
#  'dt_train_3724.jpg',
#  'dt_train_521.jpg',
#  'dt_train_2657.jpg',
#  'dt_train_1935.jpg',
#  'dt_train_1189.jpg',
#  'dt_train_3980.jpg',
#  'dt_train_3113.jpg',
#  'dt_train_1327.jpg',
#  'dt_train_491.jpg',
#  'dt_train_3505.jpg',
#  'dt_train_2817.jpg',
#  'dt_train_742.jpg',
#  'dt_train_854.jpg',
#  'dt_train_365.jpg',
#  'dt_train_462.jpg',
#  'dt_train_2355.jpg',
#  'dt_train_2734.jpg',
#  'dt_train_3521.jpg',
#  'dt_train_1963.jpg',
#  'dt_train_1197.jpg',
#  'dt_train_610.jpg',
#  'dt_train_230.jpg',
#  'dt_train_987.jpg',
#  'dt_train_1473.jpg',
#  'dt_train_1465.jpg',
#  'dt_train_803.jpg',
#  'dt_train_965.jpg',
#  'dt_train_1098.jpg',
#  'dt_train_2430.jpg',
#  'dt_train_1889.jpg',
#  'dt_train_415.jpg',
#  'dt_train_2635.jpg',
#  'dt_train_20.jpg',
#  'dt_train_3230.jpg',
#  'dt_train_1675.jpg',
#  'dt_train_1367.jpg',
#  'dt_train_109.jpg',
#  'dt_train_843.jpg',
#  'dt_train_2197.jpg',
#  'dt_train_3320.jpg',
#  'dt_train_2424.jpg',
#  'dt_train_2751.jpg',
#  'dt_train_3240.jpg',
#  'dt_train_2767.jpg',
#  'dt_train_607.jpg',
#  'dt_train_2070.jpg',
#  'dt_train_3283.jpg',
#  'dt_train_3476.jpg',
#  'dt_train_2511.jpg',
#  'dt_train_3686.jpg',
#  'dt_train_3758.jpg',
#  'dt_train_3677.jpg',
#  'dt_train_2812.jpg',
#  'dt_train_217.jpg',
#  'dt_train_3767.jpg',
#  'dt_train_3166.jpg',
#  'dt_train_1461.jpg',
#  'dt_train_3567.jpg',
#  'dt_train_935.jpg',
#  'dt_train_227.jpg',
#  'dt_train_1762.jpg',
#  'dt_train_2404.jpg',
#  'dt_train_2560.jpg',
#  'dt_train_2563.jpg',
#  'dt_train_464.jpg',
#  'dt_train_2272.jpg',
#  'dt_train_434.jpg',
#  'dt_train_2707.jpg',
#  'dt_train_1112.jpg',
#  'dt_train_263.jpg',
#  'dt_train_1573.jpg',
#  'dt_train_3461.jpg',
#  'dt_train_3821.jpg',
#  'dt_train_3137.jpg',
#  'dt_train_2970.jpg',
#  'dt_train_410.jpg',
#  'dt_train_1891.jpg',
#  'dt_train_2017.jpg',
#  'dt_train_3177.jpg',
#  'dt_train_4113.jpg',
#  'dt_train_361.jpg',
#  'dt_train_2647.jpg',
#  'dt_train_1180.jpg',
#  'dt_train_2126.jpg',
#  'dt_train_1101.jpg',
#  'dt_train_1072.jpg',
#  'dt_train_1073.jpg',
#  'dt_train_3803.jpg',
#  'dt_train_1616.jpg',
#  'dt_train_1431.jpg',
#  'dt_train_2773.jpg',
#  'dt_train_340.jpg',
#  'dt_train_2011.jpg',
#  'dt_train_1799.jpg',
#  'dt_train_1278.jpg',
#  'dt_train_1571.jpg',
#  'dt_train_3431.jpg',
#  'dt_train_1350.jpg',
#  'dt_train_2108.jpg',
#  'dt_train_894.jpg',
#  'dt_train_208.jpg',
#  'dt_train_2004.jpg',
#  'dt_train_313.jpg',
#  'dt_train_2861.jpg',
#  'dt_train_2055.jpg',
#  'dt_train_2073.jpg',
#  'dt_train_1438.jpg',
#  'dt_train_2973.jpg',
#  'dt_train_2093.jpg',
#  'dt_train_2157.jpg',
#  'dt_train_3003.jpg',
#  'dt_train_2015.jpg',
#  'dt_train_4110.jpg',
#  'dt_train_3225.jpg',
#  'dt_train_3481.jpg',
#  'dt_train_2866.jpg',
#  'dt_train_2936.jpg',
#  'dt_train_498.jpg',
#  'dt_train_2251.jpg',
#  'dt_train_1967.jpg',
#  'dt_train_373.jpg',
#  'dt_train_184.jpg',
#  'dt_train_3131.jpg',
#  'dt_train_1456.jpg',
#  'dt_train_3252.jpg',
#  'dt_train_4048.jpg',
#  'dt_train_1782.jpg',
#  'dt_train_1688.jpg',
#  'dt_train_689.jpg',
#  'dt_train_2842.jpg',
#  'dt_train_3774.jpg',
#  'dt_train_3533.jpg',
#  'dt_train_1362.jpg',
#  'dt_train_37.jpg',
#  'dt_train_2230.jpg',
#  'dt_train_817.jpg',
#  'dt_train_1366.jpg',
#  'dt_train_2916.jpg',
#  'dt_train_1898.jpg',
#  'dt_train_3121.jpg',
#  'dt_train_2052.jpg',
#  'dt_train_4045.jpg',
#  'dt_train_2912.jpg',
#  'dt_train_1017.jpg',
#  'dt_train_1368.jpg',
#  'dt_train_1290.jpg',
#  'dt_train_2633.jpg',
#  'dt_train_990.jpg',
#  'dt_train_199.jpg',
#  'dt_train_216.jpg',
#  'dt_train_1795.jpg',
#  'dt_train_1347.jpg',
#  'dt_train_3101.jpg',
#  'dt_train_1861.jpg',
#  'dt_train_1793.jpg',
#  'dt_train_3364.jpg',
#  'dt_train_3777.jpg',
#  'dt_train_2931.jpg',
#  'dt_train_3670.jpg',
#  'dt_train_2731.jpg',
#  'dt_train_1660.jpg',
#  'dt_train_2005.jpg',
#  'dt_train_1482.jpg',
#  'dt_train_401.jpg',
#  'dt_train_2838.jpg',
#  'dt_train_1924.jpg',
#  'dt_train_2091.jpg',
#  'dt_train_1382.jpg',
#  'dt_train_4053.jpg',
#  'dt_train_1103.jpg',
#  'dt_train_3217.jpg',
#  'dt_train_3720.jpg',
#  'dt_train_1488.jpg',
#  'dt_train_2619.jpg',
#  'dt_train_3722.jpg',
#  'dt_train_407.jpg',
#  'dt_train_2788.jpg',
#  'dt_train_1487.jpg',
#  'dt_train_2233.jpg',
#  'dt_train_3345.jpg',
#  'dt_train_3438.jpg',
#  'dt_train_280.jpg',
#  'dt_train_3562.jpg',
#  'dt_train_2540.jpg',
#  'dt_train_92.jpg',
#  'dt_train_1777.jpg',
#  'dt_train_3334.jpg',
#  'dt_train_193.jpg',
#  'dt_train_2872.jpg',
#  'dt_train_1570.jpg',
#  'dt_train_337.jpg',
#  'dt_train_2025.jpg',
#  'dt_train_273.jpg',
#  'dt_train_2851.jpg',
#  'dt_train_3904.jpg',
#  'dt_train_1108.jpg',
#  'dt_train_3653.jpg',
#  'dt_train_1150.jpg',
#  'dt_train_4070.jpg',
#  'dt_train_2188.jpg',
#  'dt_train_1928.jpg',
#  'dt_train_3082.jpg',
#  'dt_train_3903.jpg',
#  'dt_train_3897.jpg',
#  'dt_train_1137.jpg',
#  'dt_train_4073.jpg',
#  'dt_train_713.jpg',
#  'dt_train_939.jpg',
#  'dt_train_634.jpg',
#  'dt_train_1811.jpg',
#  'dt_train_1950.jpg',
#  'dt_train_3923.jpg',
#  'dt_train_657.jpg',
#  'dt_train_841.jpg',
#  'dt_train_3206.jpg',
#  'dt_train_2752.jpg',
#  'dt_train_3056.jpg',
#  'dt_train_3063.jpg',
#  'dt_train_3780.jpg',
#  'dt_train_1885.jpg',
#  'dt_train_331.jpg',
#  'dt_train_427.jpg',
#  'dt_train_3799.jpg',
#  'dt_train_3301.jpg',
#  'dt_train_3981.jpg',
#  'dt_train_2772.jpg',
#  'dt_train_554.jpg',
#  'dt_train_3818.jpg',
#  'dt_train_21.jpg',
#  'dt_train_3232.jpg',
#  'dt_train_1681.jpg',
#  'dt_train_389.jpg',
#  'dt_train_1410.jpg',
#  'dt_train_320.jpg',
#  'dt_train_3023.jpg',
#  'dt_train_1767.jpg',
#  'dt_train_2439.jpg',
#  'dt_train_1370.jpg',
#  'dt_train_2481.jpg',
#  'dt_train_315.jpg',
#  'dt_train_2852.jpg',
#  'dt_train_1737.jpg',
#  'dt_train_3580.jpg',
#  'dt_train_2887.jpg',
#  'dt_train_645.jpg',
#  'dt_train_3872.jpg',
#  'dt_train_2673.jpg',
#  'dt_train_111.jpg',
#  'dt_train_898.jpg',
#  'dt_train_3503.jpg',
#  'dt_train_1080.jpg',
#  'dt_train_1406.jpg',
#  'dt_train_1615.jpg',
#  'dt_train_3764.jpg',
#  'dt_train_3247.jpg',
#  'dt_train_1829.jpg',
#  'dt_train_1466.jpg',
#  'dt_train_522.jpg',
#  'dt_train_2354.jpg',
#  'dt_train_2335.jpg',
#  'dt_train_3279.jpg',
#  'dt_train_3221.jpg',
#  'dt_train_3534.jpg',
#  'dt_train_707.jpg',
#  'dt_train_4094.jpg',
#  'dt_train_1801.jpg',
#  'dt_train_2795.jpg',
#  'dt_train_1413.jpg',
#  'dt_train_2567.jpg',
#  'dt_train_605.jpg',
#  'dt_train_924.jpg',
#  'dt_train_2164.jpg',
#  'dt_train_761.jpg',
#  'dt_train_1915.jpg',
#  'dt_train_1792.jpg',
#  'dt_train_22.jpg',
#  'dt_train_1896.jpg',
#  'dt_train_915.jpg',
#  'dt_train_272.jpg',
#  'dt_train_812.jpg',
#  'dt_train_3147.jpg',
#  'dt_train_2764.jpg',
#  'dt_train_2462.jpg',
#  'dt_train_1498.jpg',
#  'dt_train_1291.jpg',
#  'dt_train_3193.jpg',
#  'dt_train_1401.jpg',
#  'dt_train_2193.jpg',
#  'dt_train_2189.jpg',
#  'dt_train_1006.jpg',
#  'dt_train_2523.jpg',
#  'dt_train_2083.jpg',
#  'dt_train_3982.jpg',
#  'dt_train_3772.jpg',
#  'dt_train_1051.jpg',
#  'dt_train_476.jpg',
#  'dt_train_4123.jpg',
#  'dt_train_2648.jpg',
#  'dt_train_1038.jpg',
#  'dt_train_871.jpg',
#  'dt_train_2152.jpg',
#  'dt_train_1957.jpg',
#  'dt_train_4042.jpg',
#  'dt_train_3508.jpg',
#  'dt_train_3448.jpg',
#  'dt_train_1644.jpg',
#  'dt_train_2846.jpg',
#  'dt_train_1127.jpg',
#  'dt_train_3967.jpg',
#  'dt_train_2224.jpg',
#  'dt_train_1884.jpg',
#  'dt_train_3413.jpg',
#  'dt_train_281.jpg',
#  'dt_train_1944.jpg',
#  'dt_train_3901.jpg',
#  'dt_train_1825.jpg',
#  'dt_train_1271.jpg',
#  'dt_train_2595.jpg',
#  'dt_train_4111.jpg',
#  'dt_train_3509.jpg',
#  'dt_train_296.jpg',
#  'dt_train_1958.jpg',
#  'dt_train_3300.jpg',
#  'dt_train_3661.jpg',
#  'dt_train_1607.jpg',
#  'dt_train_3263.jpg',
#  'dt_train_2967.jpg',
#  'dt_train_3590.jpg',
#  'dt_train_3465.jpg',
#  'dt_train_919.jpg',
#  'dt_train_835.jpg',
#  'dt_train_2758.jpg',
#  'dt_train_1639.jpg',
#  'dt_train_2499.jpg',
#  'dt_train_1105.jpg',
#  'dt_train_3127.jpg',
#  'dt_train_2369.jpg',
#  'dt_train_3915.jpg',
#  'dt_train_1786.jpg',
#  'dt_train_2737.jpg',
#  'dt_train_1361.jpg',
#  'dt_train_1759.jpg',
#  'dt_train_2913.jpg',
#  'dt_train_603.jpg',
#  'dt_train_1223.jpg',
#  'dt_train_1920.jpg',
#  'dt_train_4121.jpg',
#  'dt_train_3065.jpg',
#  'dt_train_1604.jpg',
#  'dt_train_891.jpg',
#  'dt_train_910.jpg',
#  'dt_train_3218.jpg',
#  'dt_train_2566.jpg',
#  'dt_train_391.jpg',
#  'dt_train_412.jpg',
#  'dt_train_2810.jpg',
#  'dt_train_546.jpg',
#  'dt_train_3260.jpg',
#  'dt_train_789.jpg',
#  'dt_train_684.jpg',
#  'dt_train_2554.jpg',
#  'dt_train_2027.jpg',
#  'dt_train_3079.jpg',
#  'dt_train_13.jpg',
#  'dt_train_2282.jpg',
#  'dt_train_3948.jpg',
#  'dt_train_2079.jpg',
#  'dt_train_449.jpg',
#  'dt_train_659.jpg',
#  'dt_train_3798.jpg',
#  'dt_train_727.jpg',
#  'dt_train_3634.jpg',
#  'dt_train_3961.jpg',
#  'dt_train_1241.jpg',
#  'dt_train_568.jpg',
#  'dt_train_2031.jpg',
#  'dt_train_2331.jpg',
#  'dt_train_806.jpg',
#  'dt_train_137.jpg',
#  'dt_train_2253.jpg',
#  'dt_train_2285.jpg',
#  'dt_train_3973.jpg',
#  'dt_train_1582.jpg',
#  'dt_train_4052.jpg',
#  'dt_train_762.jpg',
#  'dt_train_3700.jpg',
#  'dt_train_2291.jpg',
#  'dt_train_3462.jpg',
#  'dt_train_2713.jpg',
#  'dt_train_2690.jpg',
#  'dt_train_2245.jpg',
#  'dt_train_1634.jpg',
#  'dt_train_2988.jpg',
#  'dt_train_3658.jpg',
#  'dt_train_2304.jpg',
#  'dt_train_1292.jpg',
#  'dt_train_2222.jpg',
#  'dt_train_3096.jpg',
#  'dt_train_1593.jpg',
#  'dt_train_2198.jpg',
#  'dt_train_1453.jpg',
#  'dt_train_2127.jpg',
#  'dt_train_2351.jpg',
#  'dt_train_3662.jpg',
#  'dt_train_2840.jpg',
#  'dt_train_3211.jpg',
#  'dt_train_4046.jpg',
#  'dt_train_2876.jpg',
#  'dt_train_3519.jpg',
#  'dt_train_32.jpg',
#  'dt_train_3808.jpg',
#  'dt_train_2927.jpg',
#  'dt_train_113.jpg',
#  'dt_train_1620.jpg',
#  'dt_train_1701.jpg',
#  'dt_train_2016.jpg',
#  'dt_train_3418.jpg',
#  'dt_train_2853.jpg',
#  'dt_train_2206.jpg',
#  'dt_train_1364.jpg',
#  'dt_train_454.jpg',
#  'dt_train_2170.jpg',
#  'dt_train_304.jpg',
#  'dt_train_1172.jpg',
#  'dt_train_3159.jpg',
#  'dt_train_4050.jpg',
#  'dt_train_2718.jpg',
#  'dt_train_2454.jpg',
#  'dt_train_2406.jpg',
#  'dt_train_857.jpg',
#  'dt_train_1205.jpg',
#  'dt_train_651.jpg',
#  'dt_train_1272.jpg',
#  'dt_train_2301.jpg',
#  'dt_train_863.jpg',
#  'dt_train_1046.jpg',
#  'dt_train_1177.jpg',
#  'dt_train_3657.jpg',
#  'dt_train_271.jpg',
#  'dt_train_567.jpg',
#  'dt_train_2754.jpg',
#  'dt_train_2305.jpg',
#  'dt_train_1730.jpg',
#  'dt_train_701.jpg',
#  'dt_train_3856.jpg',
#  'dt_train_3893.jpg',
#  'dt_train_1373.jpg',
#  'dt_train_2559.jpg',
#  'dt_train_1997.jpg',
#  'dt_train_3619.jpg',
#  'dt_train_1576.jpg',
#  'dt_train_3573.jpg',
#  'dt_train_2365.jpg',
#  'dt_train_2700.jpg',
#  'dt_train_1343.jpg',
#  'dt_train_1295.jpg',
#  'dt_train_1480.jpg',
#  'dt_train_1685.jpg',
#  'dt_train_291.jpg',
#  'dt_train_913.jpg',
#  'dt_train_398.jpg',
#  'dt_train_3390.jpg',
#  'dt_train_4012.jpg',
#  'dt_train_883.jpg',
#  'dt_train_3902.jpg',
#  'dt_train_1486.jpg',
#  'dt_train_3205.jpg',
#  'dt_train_1399.jpg',
#  'dt_train_2283.jpg',
#  'dt_train_778.jpg',
#  'dt_train_2242.jpg',
#  'dt_train_3059.jpg',
#  'dt_train_2692.jpg',
#  'dt_train_2248.jpg',
#  ...]

# %%
file_path="/home/cpslab/Akshay KR/finished/train/dataraw/hires/" #path

# %%
def create_lr_data(img_path="",img_file="",compression_factor=10,w=0,h=0):
  
  img=cv2.imread(img_path+img_file)
  if w!=0 and h!=0:
    newimg1=cv2.resize(img,(w,h),interpolation=cv2.INTER_CUBIC)
    # cv2_imshow(newimg1)
    return newimg1
  else:
    w=img.shape[1]  
    h=img.shape[0]  
    newimg1=cv2.resize(img,(int(w/compression_factor),int(h/compression_factor)),interpolation=cv2.INTER_CUBIC)
    # cv2_imshow(newimg1)
    return newimg1

# %%
hr_arr=[]
lr_arr=[]
error_images=[]
for imgs in os.listdir(file_path):
  try:
    img_hr=create_lr_data(img_path=file_path, img_file=imgs, w=800,h=800)
    hr_arr.append(img_hr)
    img_lr=create_lr_data(img_path=file_path, img_file=imgs, w=200,h=200)
    lr_arr.append(img_lr)
  except Exception as e:
    print(e)
    error_images.append(imgs)
  # cv2_imshow(img_lr)
  # break
hr_arr=np.array(hr_arr)
lr_arr=np.array(lr_arr)

# %%
import tensorflow as tf
import datetime
from tensorflow import keras
from tensorflow.keras import layers
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import UpSampling2D
from keras.layers import Dense, Input, Conv2D, MaxPooling2D, Flatten, Dropout
from keras.layers import BatchNormalization
from keras.layers import Conv2DTranspose
from keras import preprocessing
from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from keras.models import load_model
from keras.callbacks import ModelCheckpoint, EarlyStopping
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #Model

# %%
###MODEL

model = keras.Sequential()

inp= tf.keras.Input(shape=(200, 200, 3))
#1st convolution
conv1 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same', name='conv_1')(inp)

#2nd convolution
conv2 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same', name='conv_2')(conv1)

#3rd convolution
conv3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same', name='conv_3')(conv2)

#skip connection between the 1st and 3rd convolution
skip = tf.keras.layers.Add()([conv1,conv3])


#bottleneck
bot = tf.keras.layers.Conv2D(64, (1,1), activation='relu')(skip)

#upsampling layer

up= tf.keras.layers.Conv2DTranspose(64, (2,2),strides=(4,4), padding='same', input_shape=(200, 200, 64))(bot)
#bottleneck
x = tf.keras.layers.Conv2D(4, (1,1), activation='relu')(up)



#RECONSTUCTION STAGE ONE

#first block

#Asymmetric convolution 1
y = tf.keras.layers.Conv2D(16, (3, 1), padding='same')(x)

y = tf.keras.layers.Conv2D(16, (1, 3), activation='relu', padding='same')(y)

#Asymmetric convolution 2
y = tf.keras.layers.Conv2D(16, (3, 1), padding='same')(y)

y = tf.keras.layers.Conv2D(16, (1, 3), activation='relu', padding='same')(y)

#Asymmetric convolution 3
y = tf.keras.layers.Conv2D(16, (3, 1), padding='same')(y)

y = tf.keras.layers.Conv2D(16, (1, 3), activation='relu', padding='same')(y)
                           
#Asymmetric convolution 4
y = tf.keras.layers.Conv2D(16, (3, 1), padding='same')(y)

y = tf.keras.layers.Conv2D(16, (1, 3), activation='relu', padding='same')(y)

#Residual connection
x = tf.keras.layers.Conv2D(16, (3, 1), padding='same')(x)  # Residual Connection

x = tf.keras.layers.Add()([x, y])  # Addition

#second block

#Asymmetric convolution 1
y = tf.keras.layers.Conv2D(16, (3, 1), padding='same')(x)

y = tf.keras.layers.Conv2D(16, (1, 3), activation='relu', padding='same')(y)

#Asymmetric convolution 2
y = tf.keras.layers.Conv2D(16, (3, 1), padding='same')(y)

y = tf.keras.layers.Conv2D(16, (1, 3), activation='relu', padding='same')(y)

#Asymmetric convolution 3
y = tf.keras.layers.Conv2D(16, (3, 1), padding='same')(y)

y = tf.keras.layers.Conv2D(16, (1, 3), activation='relu', padding='same')(y)
                           
#Asymmetric convolution 4
y = tf.keras.layers.Conv2D(16, (3, 1), padding='same')(y)

y = tf.keras.layers.Conv2D(16, (1, 3), activation='relu', padding='same')(y)

#Residual connection
x = tf.keras.layers.Conv2D(16, (3, 1), padding='same')(x)  # Residual Connection

x = tf.keras.layers.Add()([x, y])  # Addition


#RECONSTUCTION STAGE TWO
#INCEPTION BLOCK OF 5 TOWERS
                           
T11 = tf.keras.layers.Conv2D(16, (3, 1), padding='same')(x)

T12 = tf.keras.layers.Conv2D(16, (1, 3), activation='relu', padding='same')(T11)
                           
T13 = tf.keras.layers.Conv2D(16, (5, 1), padding='same')(T12)

T1 = tf.keras.layers.Conv2D(16, (1, 5), activation='relu', padding='same')(T13)
                           
                           
T21 = tf.keras.layers.Conv2D(16, (3, 1), padding='same')(x)

T22 = tf.keras.layers.Conv2D(16, (1, 3), activation='relu', padding='same')(T21)
                           
T23 = tf.keras.layers.Conv2D(16, (5, 1), padding='same')(T22)

T2 = tf.keras.layers.Conv2D(16, (1, 5), activation='relu', padding='same')(T23)
                           

T31 = tf.keras.layers.Conv2D(16, (3, 1), padding='same')(x)

T32 = tf.keras.layers.Conv2D(16, (1, 3), activation='relu', padding='same')(T31)
                           
T33 = tf.keras.layers.Conv2D(16, (5, 1), padding='same')(T32)

T3 = tf.keras.layers.Conv2D(16, (1, 5), activation='relu', padding='same')(T33)  
                           
                           
T41 = tf.keras.layers.Conv2D(16, (7, 1), padding='same')(x)

T42 = tf.keras.layers.Conv2D(16, (1, 7), activation='relu', padding='same')(T41)
                           
T43 = tf.keras.layers.Conv2D(16, (9, 1), padding='same')(T42)

T4 = tf.keras.layers.Conv2D(16, (1, 9), activation='relu', padding='same')(T43)  
                           
                           
T51 = tf.keras.layers.Conv2D(16, (7, 1), padding='same')(x)

T52 = tf.keras.layers.Conv2D(16, (1, 7), activation='relu', padding='same')(T51)
                           
T53 = tf.keras.layers.Conv2D(16, (9, 1), padding='same')(T52)

T5 = tf.keras.layers.Conv2D(16, (1, 9), activation='relu', padding='same')(T53)  
                           
                           


#CONCATENATION OF OUTPUT OF FIVE TOWERS
                 
T= tf.keras.layers.Concatenate(axis=3)([T1,T2,T3,T4,T5])


#BOTTLENECK
y_pred = tf.keras.layers.Conv2D(3, (1,1), activation='relu',)(T)

model = tf.keras.Model(inp,y_pred)
# Out:
# WARNING:tensorflow:From /home/cpslab/.local/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %% [markdown]
# ## **Model Summary**

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 150, 150, 3) 0
# __________________________________________________________________________________________________
# conv_1 (Conv2D)                 (None, 150, 150, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# conv_2 (Conv2D)                 (None, 150, 150, 64) 36928       conv_1[0][0]
# __________________________________________________________________________________________________
# conv_3 (Conv2D)                 (None, 150, 150, 64) 36928       conv_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 150, 150, 64) 0           conv_1[0][0]
#                                                                  conv_3[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 150, 150, 64) 4160        add[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 600, 600, 64) 16448       conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 600, 600, 4)  260         conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 600, 600, 16) 208         conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 600, 600, 16) 784         conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 600, 600, 16) 784         conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 600, 600, 16) 784         conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 600, 600, 16) 784         conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 600, 600, 16) 784         conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 600, 600, 16) 784         conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 600, 600, 16) 208         conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 600, 600, 16) 784         conv2d_8[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 600, 600, 16) 0           conv2d_10[0][0]
#                                                                  conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 600, 600, 16) 784         add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 600, 600, 16) 784         conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 600, 600, 16) 784         conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 600, 600, 16) 784         conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 600, 600, 16) 784         conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 600, 600, 16) 784         conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 600, 600, 16) 784         conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 600, 600, 16) 784         add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 600, 600, 16) 784         conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 600, 600, 16) 0           conv2d_19[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 600, 600, 16) 784         add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 600, 600, 16) 784         add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 600, 600, 16) 784         add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 600, 600, 16) 1808        add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 600, 600, 16) 1808        add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 600, 600, 16) 784         conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 600, 600, 16) 784         conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 600, 600, 16) 784         conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 600, 600, 16) 1808        conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 600, 600, 16) 1808        conv2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 600, 600, 16) 1296        conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 600, 600, 16) 1296        conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 600, 600, 16) 1296        conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 600, 600, 16) 2320        conv2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 600, 600, 16) 2320        conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 600, 600, 16) 1296        conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 600, 600, 16) 1296        conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 600, 600, 16) 1296        conv2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 600, 600, 16) 2320        conv2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 600, 600, 16) 2320        conv2d_38[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 600, 600, 80) 0           conv2d_23[0][0]
#                                                                  conv2d_27[0][0]
#                                                                  conv2d_31[0][0]
#                                                                  conv2d_35[0][0]
#                                                                  conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 600, 600, 3)  243         concatenate[0][0]
# ==================================================================================================
# Total params: 138,711
# Trainable params: 138,711
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
Adam1 = keras.optimizers.Adam(learning_rate=0.0003)

# %%
model.compile(loss ='mean_squared_error', optimizer=Adam1, metrics=['accuracy'])

# %% [markdown]
# # **Training using Tensorboard**

# %%
# Load the TensorBoard notebook extension.
# %load_ext tensorboard

# %%
import tensorboard
tensorboard.__version__
# Out:
# '1.15.0'

# %%
log_dir = "logs_150/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

# %%
my_callbacks = [tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)]

# %%
model.fit(lr_arr, hr_arr, epochs=200, batch_size=2, callbacks=my_callbacks)
# Out:
# Train on 4128 samples
# Epoch 1/200
# 4128/4128 [==============================] - 1388s 336ms/sample - loss: 556.4966 - acc: 0.7417
# Epoch 2/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 330.5498 - acc: 0.8486
# Epoch 3/200
# 4128/4128 [==============================] - 1373s 332ms/sample - loss: 315.8782 - acc: 0.8622
# Epoch 4/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 310.4558 - acc: 0.8679
# Epoch 5/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 307.5001 - acc: 0.8638
# Epoch 6/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 301.1514 - acc: 0.8711
# Epoch 7/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 300.0296 - acc: 0.8780
# Epoch 8/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 297.0106 - acc: 0.8747
# Epoch 9/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 294.9931 - acc: 0.8798
# Epoch 10/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 293.6147 - acc: 0.8812
# Epoch 11/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 293.3118 - acc: 0.8785
# Epoch 12/200
# 4128/4128 [==============================] - 1373s 333ms/sample - loss: 290.3873 - acc: 0.8834
# Epoch 13/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 289.8681 - acc: 0.8848
# Epoch 14/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 290.4965 - acc: 0.8853
# Epoch 15/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 287.6709 - acc: 0.8895
# Epoch 16/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 287.9920 - acc: 0.8847
# Epoch 17/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 286.6237 - acc: 0.8864
# Epoch 18/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 287.0999 - acc: 0.8854
# Epoch 19/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 285.4975 - acc: 0.8878
# Epoch 20/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 285.8204 - acc: 0.8853
# Epoch 21/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 285.5106 - acc: 0.8866
# Epoch 22/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 284.2155 - acc: 0.8883
# Epoch 23/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 283.9919 - acc: 0.8875
# Epoch 24/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 283.2912 - acc: 0.8898
# Epoch 25/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 283.2983 - acc: 0.8884
# Epoch 26/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 282.7765 - acc: 0.8899
# Epoch 27/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 282.3309 - acc: 0.8898
# Epoch 28/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 281.9685 - acc: 0.8879
# Epoch 29/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 282.3840 - acc: 0.8903
# Epoch 30/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 281.5395 - acc: 0.8902
# Epoch 31/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 281.2354 - acc: 0.8908
# Epoch 32/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 280.8255 - acc: 0.8948
# Epoch 33/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 280.5870 - acc: 0.8925
# Epoch 34/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 280.2867 - acc: 0.8947
# Epoch 35/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 280.4156 - acc: 0.8927
# Epoch 36/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 279.6112 - acc: 0.8964
# Epoch 37/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 279.9420 - acc: 0.8914
# Epoch 38/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 279.5964 - acc: 0.8947
# Epoch 39/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 279.5828 - acc: 0.8959
# Epoch 40/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 278.7240 - acc: 0.8955
# Epoch 41/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 279.8139 - acc: 0.8922
# Epoch 42/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 278.8909 - acc: 0.8968
# Epoch 43/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 278.5569 - acc: 0.8938
# Epoch 44/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 278.4409 - acc: 0.8940
# Epoch 45/200
# 4128/4128 [==============================] - 1418s 344ms/sample - loss: 278.5424 - acc: 0.8940
# Epoch 46/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 278.0425 - acc: 0.8965
# Epoch 47/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 278.2096 - acc: 0.8931
# Epoch 48/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 277.3125 - acc: 0.8989
# Epoch 49/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 277.4383 - acc: 0.8948
# Epoch 50/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 277.1694 - acc: 0.8940
# Epoch 51/200
# 4128/4128 [==============================] - 1372s 332ms/sample - loss: 277.6588 - acc: 0.8967
# Epoch 52/200
# 4128/4128 [==============================] - 1393s 337ms/sample - loss: 276.9483 - acc: 0.8971
# Epoch 53/200
# 4128/4128 [==============================] - 1436s 348ms/sample - loss: 277.0630 - acc: 0.8974
# Epoch 54/200
# 4128/4128 [==============================] - 1402s 340ms/sample - loss: 276.9001 - acc: 0.8958
# Epoch 55/200
# 4128/4128 [==============================] - 1406s 341ms/sample - loss: 276.9583 - acc: 0.8950
# Epoch 56/200
# 2864/4128 [===================>..........] - ETA: 8:01 - loss: 275.8369 - acc: 0.8960

# %%
# !mkdir -p saved_model
model.save('saved_model/my_model_200_')

# %%
# !mkdir -p saved_model_h5
model.save('my_h5_model_200_.h5')

# %%
# %tensorboard --logdir logs

# %% [markdown]
# ## Preprocessed and processed image outputs

# %%
img_lr.shape

# %%
cv2.imshow('image',img_lr.reshape(200,200,3))

# %%
cv2.imshow('image',img_hr)

# %%
img_lr=img_lr.reshape((1,)+img_lr.shape)

# %%
img_lr.shape

# %%
out=model.predict([img_lr])

# %% [markdown]
# # **SSIM** **CALCULATION**

# %%
im1 = tf.image.convert_image_dtype(img_hr, tf.float32)
im2 = tf.image.convert_image_dtype(out, tf.float32)

# %%
ssim2 = tf.image.ssim(im1, im2, max_val=1.0, filter_size=11,filter_sigma=1.5, k1=0.01, k2=0.03)

# %%
print(ssim2)

# %% [markdown]
# # **OUTPUT IMAGE**

# %%
cv2_imshow(out.reshape(800,800,3))

# %%
model.history

# %%
dot_img_file = './drive/My Drive/model_1.png'
tf.keras.utils.plot_model(model, to_file=dot_img_file, dpi=300,show_shapes=True)

# %%
# !tensorboard --logdir=logs --host localhost --port 8088
